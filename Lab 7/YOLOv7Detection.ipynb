# %% [markdown]
# Import Pytorch and Sys package.
#
# Import cv2 to read images and use patplotlib to show graphs.

# %%
import numpy as np
import cv2 as cv  # import OpenCV
img = cv.imread('UTS central.jpg')  #load the image
print (img.shape) 
print (img[0,0]) 
print (img[0,0,2])

# %%
pip install opencv-python

# %%
import sys
import torch
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
print(f"Python version: {sys.version}, {sys.version_info} ")
print(f"Pytorch version: {torch.__version__} ")

# %% [markdown]
# Check the GPU useage and see details.

# %%
# !nvidia-smi

# %% [markdown]
# Download YOLOv7 code from github, and go to yolov7 folder by using 'cd' command.

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !ls

# %% [markdown]
# Download trained weights.
# You can download different trained weights from https://github.com/WongKinYiu/yolov7/releases/tag/v0.1.
#
# Using !wget command and https://github.com/WongKinYiu/yolov7/releases/download/v0.1/'the trained weights'

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %% [markdown]
# Define a funtion to view the image that you prepare.

# %%
# define helper functions to show images
def imShow(path):

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# Fill in the image path to this function.
#
# There are several images in folder: ''inference/images/'', or you can upload the images by yourself.

# %%
imShow("inference/images/bus.jpg")

# %% [markdown]
# Using detect.py file to detect objects.
#
# **Step 1**. Prepare an image for detection.
#
# **Step 2**. Upload it to colab folder. For example: yolov7/inference/image
#
# **Step 3**. Run detect.py to detect objects.
#
# Meaning of main arguments:
#
# '**--weights**', nargs='+', type=str, default='yolov7.pt', help='model.pt path(s)'
#
# '**--source**', type=str, default='inference/images', help='source'  # file/folder, 0 for webcam
#
# '**--img-size**', type=int, default=640, help='inference size (pixels)'
#
# '**--conf-thres**', type=float, default=0.25, help='object confidence threshold'
#
# '**--iou-thres**', type=float, default=0.45, help='IOU threshold for NMS'
#
# '**--device**', default='', help='cuda device, i.e. 0 or 0,1,2,3 or cpu'
#
# '**--view-img**', action='store_true', help='display results'
#
# '**--classes**', nargs='+', type=int, help='filter by class: --class 0, or --class 0 2 3'
#
# '**--project**', default='runs/detect', help='save results to project/name'
#
# The detected image is saved in '--project' folder. For example: 'runs/detect'

# %%
!# Detection
# !python detect.py --weights yolov7.pt --conf 0.25 --img-size 640 --source inference/images/bus.jpg

# %% [markdown]
# Go to the target folder to check the image.
#
# Or using imShow function by filling the image path.

# %%
imShow("runs/detect/exp/bus.jpg")
